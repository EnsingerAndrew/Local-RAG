# %% [markdown]
# ## 2.  bge-base-en-v1.5

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer("BAAI/bge-base-en-v1.5")
model.save("./bge-base-en-v1.5")

# %% [markdown]
# ## 3. multi-qa-mpnet-base-dot-v1

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer("sentence-transformers/multi-qa-mpnet-base-dot-v1")
model.save("./multi-qa-mpnet-base-dot-v1")

# %% [markdown]
# ## 4. NER

# %%
from transformers import pipeline
ner = pipeline("token-classification", model="dslim/bert-base-NER", aggregation_strategy="simple")
save_dir = "NER"
ner.model.save_pretrained(save_dir)
ner.tokenizer.save_pretrained(save_dir)
